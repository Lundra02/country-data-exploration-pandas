# %% [markdown]
# <a href="https://colab.research.google.com/github/Lundra02/country-data-exploration-pandas/blob/main/country-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import isin
import pandas as pd

df = pd.read_csv('world_countries_unordered.csv')

num_rows = len(df)
num_columns = len(df.columns)

columns_df = df.columns

five_rows = df.head()

ten_rows = df.head(10)

last_rows = df.tail()

info_df = df.info()
countries = df[['Continent', 'Country', 'Capital']]
top_10 = df[df['Rank'] < 10]
pd.set_option('display.max.rows', 100)

# my_fav_countries = df.loc[['Albania', 'Argentina', 'Austria']]

# df.set_index('Country', inplace=True)

my_fav_countries = ['Albania', 'Austria', 'Argentina']
is_true = df[df['Country'].isin(my_fav_countries)]

republic_countries = df[df['Country'].str.contains('Republic')]

belove_20 = df[df['Rank'] < 20]
belove_50 = df[df['Rank'] < 50]


sort_data = df.sort_values(by='Country', axis=0)
sort_desc_data = df.sort_values(by='Country', axis=0, ascending=False)
sort_continent = df.sort_values(by=['Continent', 'Country'], axis=0)


europe = df[['Country', 'Continent']]
europe = europe.set_index('Continent')
europe = europe.filter(items=['Europe'], axis=0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      100 non-null    object
#  1   Rank                         100 non-null    int64
#  2   Capital                      100 non-null    object
#  3   Continent                    100 non-null    object
#  4   Population                   100 non-null    int64
#  5   Area                         100 non-null    int64
#  6   Density                      100 non-null    float64
#  7   World Population Percentage  100 non-null    float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.4+ KB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_948/3057748607.py in <cell line: 0>()
#      40 europe = df[['Country', 'Continent']]
#      41 europe = europe.set_index('Continent')
# ---> 42 europe = europe.filter(items=['Europe'], axis=0)
#      43
#      44
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in filter(self, items, like, regex, axis)
#    5796                 items = items.astype(labels.dtype)
#    5797             # error: Keywords must be strings
# -> 5798             return self.reindex(**{name: items})  # type: ignore[misc]
#    5799         elif like:
#    5800
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/frame.py in reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5376         tolerance=None,
#    5377     ) -> DataFrame:
# -> 5378         return super().reindex(
#    5379             labels=labels,
#    5380             index=index,
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5608
#    5609         # perform the reindex on the axes
# -> 5610         return self._reindex_axes(
#    5611             axes, level, limit, tolerance, method, fill_value, copy
#    5612         ).__finalize__(self, method="reindex")
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5631
#    5632             ax = self._get_axis(a)
# -> 5633             new_index, indexer = ax.reindex(
#    5634                 labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5635             )
#
# /usr/local/lib/python3.13/dist-packages/pandas/core/indexes/base.py in reindex(self, target, method, level, limit, tolerance)
#    4427                 elif not self.is_unique:
#    4428                     # GH#42568
# -> 4429                     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4430                 else:
#    4431                     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels
